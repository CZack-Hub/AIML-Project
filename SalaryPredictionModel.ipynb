# %%
import pandas as pd
import numpy as np
data = pd.read_csv('/content/drive/MyDrive/salary_prediction_data.csv')
data.head()
# Out:
#      Education  Experience  Location Job_Title  Age  Gender         Salary
# 0  High School           8     Urban   Manager   63    Male   84620.053665
# 1          PhD          11  Suburban  Director   59    Male  142591.255894
# 2     Bachelor          28  Suburban   Manager   61  Female   97800.255404
# 3  High School          29     Rural  Director   45    Male   96834.671282
# 4          PhD          25     Urban   Analyst   26  Female  132157.786175

# %%
data.tail(10)
# Out:
#        Education  Experience  Location Job_Title  Age  Gender         Salary
# 990       Master          19  Suburban  Director   59  Female  128161.591560
# 991  High School           6     Rural   Manager   52    Male   55762.985476
# 992       Master          25     Rural  Director   50  Female  127400.657322
# 993  High School          23     Urban  Director   40    Male   98276.767603
# 994       Master          19     Urban  Director   40  Female  140086.471247
# 995  High School           8  Suburban   Analyst   25  Female   64683.389864
# 996  High School          24     Urban  Engineer   30  Female   74468.205020
# 997       Master          18     Rural   Analyst   44    Male   98207.026024
# 998     Bachelor          27  Suburban  Director   31  Female  108544.922720
# 999  High School          25     Urban  Director   41  Female   71077.000066

# %%
data.shape
# Out:
# (1000, 7)

# %%
data.isna().sum()
# Out:
# Education     0
# Experience    0
# Location      0
# Job_Title     0
# Age           0
# Gender        0
# Salary        0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isna().sum()
# Out:
# Education     0
# Experience    0
# Location      0
# Job_Title     0
# Age           0
# Gender        0
# Salary        0
# dtype: int64

# %%
data.shape
# Out:
# (1000, 7)

# %%
print(data['Education'].value_counts())
# Out:
# Education
# High School    255
# Bachelor       253
# PhD            251
# Master         241
# Name: count, dtype: int64

# %%
print(data['Job_Title'].value_counts())
# Out:
# Job_Title
# Director    275
# Analyst     255
# Manager     241
# Engineer    229
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['Education', 'Experience', 'Location', 'Job_Title', 'Age', 'Gender',
#        'Salary'],
#       dtype='object')

# %%
data['Location'].value_counts()
# Out:
# Location
# Suburban    345
# Rural       345
# Urban       310
# Name: count, dtype: int64

# %%
data['Experience'].value_counts().sort_index(ascending=False)
# Out:
# Experience
# 29    31
# 28    34
# 27    30
# 26    27
# 25    37
# 24    38
# 23    27
# 22    35
# 21    28
# 20    43
# 19    36
# 18    42
# 17    48
# 16    40
# 15    26
# 14    29
# 13    37
# 12    31
# 11    33
# 10    22
# 9     25
# 8     39
# 7     35
# 6     43
# 5     42
# 4     36
# 3     33
# 2     38
# 1     35
# Name: count, dtype: int64

# %%
data['Age'].value_counts().sort_index(ascending=False)
# Out:
# Age
# 64    21
# 63    28
# 62    30
# 61    24
# 60    33
# 59    30
# 58    30
# 57    22
# 56    21
# 55    14
# 54    25
# 53    18
# 52    20
# 51    15
# 50    22
# 49    25
# 48    23
# 47    16
# 46    15
# 45    25
# 44    27
# 43    19
# 42    24
# 41    28
# 40    20
# 39    19
# 38    15
# 37    21
# 36    22
# 35    18
# 34    19
# 33    18
# 32    13
# 31    23
# 30    14
# 29    19
# 28    15
# 27    33
# 26    22
# 25    24
# 24    29
# 23    24
# 22    19
# 21    30
# 20    28
# Name: count, dtype: int64

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Male      516
# Female    484
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (1000, 7)

# %%
import matplotlib.pyplot as plt
plt.boxplot(data['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7c44507c54d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7c44507c73d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7c44507c56d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7c44508988d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7c4450899250>],
#  'means': []}

# %%
plt.bar(data['Education'],data['Salary'])
plt.xlabel('Education')
plt.ylabel('Salary')
plt.title('Salary vs Education')
plt.show()

# %%
plt.bar(data['Experience'],data['Salary'])
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.title('Salary vs Experience')
plt.show()

# %%
plt.hist(data['Age'])
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.bar_label(plt.gca().containers[0])
plt.show()

# %%
data
# Out:
#        Education  Experience  Location Job_Title  Age  Gender         Salary
# 0    High School           8     Urban   Manager   63    Male   84620.053665
# 1            PhD          11  Suburban  Director   59    Male  142591.255894
# 2       Bachelor          28  Suburban   Manager   61  Female   97800.255404
# 3    High School          29     Rural  Director   45    Male   96834.671282
# 4            PhD          25     Urban   Analyst   26  Female  132157.786175
# ..           ...         ...       ...       ...  ...     ...            ...
# 995  High School           8  Suburban   Analyst   25  Female   64683.389864
# 996  High School          24     Urban  Engineer   30  Female   74468.205020
# 997       Master          18     Rural   Analyst   44    Male   98207.026024
# 998     Bachelor          27  Suburban  Director   31  Female  108544.922720
# 999  High School          25     Urban  Director   41  Female   71077.000066
#
# [1000 rows x 7 columns]

# %%
data
# Out:
#        Education  Experience  Location Job_Title  Age  Gender         Salary
# 0    High School           8     Urban   Manager   63    Male   84620.053665
# 1            PhD          11  Suburban  Director   59    Male  142591.255894
# 2       Bachelor          28  Suburban   Manager   61  Female   97800.255404
# 3    High School          29     Rural  Director   45    Male   96834.671282
# 4            PhD          25     Urban   Analyst   26  Female  132157.786175
# ..           ...         ...       ...       ...  ...     ...            ...
# 995  High School           8  Suburban   Analyst   25  Female   64683.389864
# 996  High School          24     Urban  Engineer   30  Female   74468.205020
# 997       Master          18     Rural   Analyst   44    Male   98207.026024
# 998     Bachelor          27  Suburban  Director   31  Female  108544.922720
# 999  High School          25     Urban  Director   41  Female   71077.000066
#
# [1000 rows x 7 columns]

# %%
x=data.drop('Salary',axis=1)
y=data['Salary']

# %%
x
# Out:
#        Education  Experience  Location Job_Title  Age  Gender
# 0    High School           8     Urban   Manager   63    Male
# 1            PhD          11  Suburban  Director   59    Male
# 2       Bachelor          28  Suburban   Manager   61  Female
# 3    High School          29     Rural  Director   45    Male
# 4            PhD          25     Urban   Analyst   26  Female
# ..           ...         ...       ...       ...  ...     ...
# 995  High School           8  Suburban   Analyst   25  Female
# 996  High School          24     Urban  Engineer   30  Female
# 997       Master          18     Rural   Analyst   44    Male
# 998     Bachelor          27  Suburban  Director   31  Female
# 999  High School          25     Urban  Director   41  Female
#
# [1000 rows x 6 columns]

# %%
y
# Out:
# 0       84620.053665
# 1      142591.255894
# 2       97800.255404
# 3       96834.671282
# 4      132157.786175
#            ...
# 995     64683.389864
# 996     74468.205020
# 997     98207.026024
# 998    108544.922720
# 999     71077.000066
# Name: Salary, Length: 1000, dtype: float64

# %%
import joblib

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

numerical_features = ['Experience', 'Age']
categorical_features = ['Education', 'Location', 'Job_Title', 'Gender']

all_features = numerical_features + categorical_features
if set(x.columns) != set(all_features):
    print("Warning: Mismatch between DataFrame columns and defined features.")
    print(f"DataFrame columns: {list(x.columns)}")
    print(f"Defined features: {all_features}")

numerical_transformer = StandardScaler()
categorical_transformer = OneHotEncoder(handle_unknown='ignore')

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('cat', categorical_transformer, categorical_features)
    ])

models = {
    'LinearRegression': LinearRegression(),
    'RandomForestRegressor': RandomForestRegressor(random_state=42),
    'GradientBoostingRegressor': GradientBoostingRegressor(random_state=42),
    'KNeighborsRegressor': KNeighborsRegressor(),
    'SVR': SVR()
}

results = {}
trained_pipelines = {}

for name, model in models.items():
    print(f"\n--- Training {name} ---")

    pipe = Pipeline(steps=[('preprocessor', preprocessor),
                            ('regressor', model)])

    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

    pipe.fit(x_train, y_train)

    y_pred = pipe.predict(x_test)

    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)

    results[name] = {'MSE': mse, 'RMSE': rmse, 'R2': r2}
    trained_pipelines[name] = pipe

    print(f'{name} Mean Squared Error (MSE): {mse:.4f}')
    print(f'{name} Root Mean Squared Error (RMSE): {rmse:.4f}')
    print(f'{name} R-squared (R2): {r2:.4f}')

print("\n--- Model Performance Summary (Regression) ---")
for name, metrics in results.items():
    if isinstance(metrics, dict):
        print(f"{name}:")
        print(f"  MSE: {metrics['MSE']:.4f}")
        print(f"  RMSE: {metrics['RMSE']:.4f}")
        print(f"  R2: {metrics['R2']:.4f}")
    else:
        print(f"{name}: {metrics}")

best_model_name = max(results, key=lambda name: results[name]['R2'])
best_pipeline = trained_pipelines[best_model_name]

print(f"\nThe best model is: {best_model_name}")
print(f"The best model's regressor is: {models[best_model_name]}")

#joblib.dump(best_pipeline, "best_model.pkl")
print(f"The best model's complete pipeline has been saved to 'best_model.pkl'.")
# Out:
# --- Training LinearRegression ---
# LinearRegression Mean Squared Error (MSE): 105996277.6610
# LinearRegression Root Mean Squared Error (RMSE): 10295.4494
# LinearRegression R-squared (R2): 0.8702
#
# --- Training RandomForestRegressor ---
# RandomForestRegressor Mean Squared Error (MSE): 131047715.6412
# RandomForestRegressor Root Mean Squared Error (RMSE): 11447.6074
# RandomForestRegressor R-squared (R2): 0.8395
#
# --- Training GradientBoostingRegressor ---
# GradientBoostingRegressor Mean Squared Error (MSE): 113911195.6542
# GradientBoostingRegressor Root Mean Squared Error (RMSE): 10672.9188
# GradientBoostingRegressor R-squared (R2): 0.8605
#
# --- Training KNeighborsRegressor ---
# KNeighborsRegressor Mean Squared Error (MSE): 173204148.9759
# KNeighborsRegressor Root Mean Squared Error (RMSE): 13160.7047
# KNeighborsRegressor R-squared (R2): 0.7879
#
# --- Training SVR ---
# SVR Mean Squared Error (MSE): 822177189.2941
# SVR Root Mean Squared Error (RMSE): 28673.6323
# ...

# %%
plt.bar(results.keys(), [metrics['R2'] for metrics in results.values()], color='lightgreen')
plt.xlabel('Model')
plt.ylabel('Accuracy Score')
plt.title('Model Comparison')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
